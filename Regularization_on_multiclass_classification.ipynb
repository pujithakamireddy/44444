# %% [markdown]
# <a href="https://colab.research.google.com/github/pujithakamireddy/44444/blob/main/Regularization_on_multiclass_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from keras.datasets import reuters

# %%
(train_X, train_Y), (test_X, test_Y) = reuters.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 [==============================] - 0s 0us/step

# %%
import numpy as np
from keras.utils import to_categorical

def OneHotEncoding_fn(ReutersData, dimension=10000):

    OneHotEncoded_Data = np.zeros((len(ReutersData), dimension))
    for i, sequence in enumerate(ReutersData):

        OneHotEncoded_Data[i, sequence] = 1.
    return OneHotEncoded_Data

x_train = OneHotEncoding_fn(train_X)
x_test = OneHotEncoding_fn(test_X)

y_train = to_categorical(train_Y)
y_test = to_categorical(test_Y)

# %%
from keras import models
from keras import layers
from keras import regularizers

model = models.Sequential()

model.add(layers.Dense(64, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.01), activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.01), activation='relu'))

model.add(layers.Dense(46, activation='softmax'))

# %%
from keras import optimizers
from keras import losses
from keras import metrics

X_validation = x_train[:800]
X_train_without_val = x_train[800:]
y_validation = y_train[:800]
y_train_without_val = y_train[800:]


model.compile(optimizer=optimizers.RMSprop(learning_rate=0.001, rho=0.9),
             loss=losses.categorical_crossentropy,
             metrics=[metrics.categorical_accuracy])

history = model.fit(X_train_without_val,
                    y_train_without_val,
                    epochs=25,
                    batch_size=512,
                    validation_data=(X_validation,y_validation))
# Out:
# Epoch 1/25
# 16/16 [==============================] - 3s 118ms/step - loss: 7.1664 - categorical_accuracy: 0.3966 - val_loss: 3.6654 - val_categorical_accuracy: 0.5450
# Epoch 2/25
# 16/16 [==============================] - 2s 95ms/step - loss: 3.3446 - categorical_accuracy: 0.5614 - val_loss: 3.0939 - val_categorical_accuracy: 0.5800
# Epoch 3/25
# 16/16 [==============================] - 1s 90ms/step - loss: 3.0082 - categorical_accuracy: 0.6021 - val_loss: 2.8421 - val_categorical_accuracy: 0.6375
# Epoch 4/25
# 16/16 [==============================] - 1s 89ms/step - loss: 2.8169 - categorical_accuracy: 0.6393 - val_loss: 2.6916 - val_categorical_accuracy: 0.6687
# Epoch 5/25
# 16/16 [==============================] - 1s 89ms/step - loss: 2.6745 - categorical_accuracy: 0.6584 - val_loss: 2.5661 - val_categorical_accuracy: 0.6875
# Epoch 6/25
# 16/16 [==============================] - 2s 139ms/step - loss: 2.5655 - categorical_accuracy: 0.6707 - val_loss: 2.4744 - val_categorical_accuracy: 0.6888
# Epoch 7/25
# 16/16 [==============================] - 2s 113ms/step - loss: 2.4649 - categorical_accuracy: 0.6836 - val_loss: 2.4043 - val_categorical_accuracy: 0.6750
# Epoch 8/25
# 16/16 [==============================] - 2s 108ms/step - loss: 2.3960 - categorical_accuracy: 0.6832 - val_loss: 2.3196 - val_categorical_accuracy: 0.6875
# Epoch 9/25
# 16/16 [==============================] - 2s 105ms/step - loss: 2.3241 - categorical_accuracy: 0.6886 - val_loss: 2.2682 - val_categorical_accuracy: 0.6900
# Epoch 10/25
# 16/16 [==============================] - 1s 94ms/step - loss: 2.2711 - categorical_accuracy: 0.6898 - val_loss: 2.2177 - val_categorical_accuracy: 0.6950
# Epoch 11/25
# 16/16 [==============================] - 2s 107ms/step - loss: 2.2145 - categorical_accuracy: 0.6924 - val_loss: 2.1788 - val_categorical_accuracy: 0.6938
# Epoch 12/25
# 16/16 [==============================] - 2s 101ms/step - loss: 2.1805 - categorical_accuracy: 0.6940 - val_loss: 2.1326 - val_categorical_accuracy: 0.6925
# Epoch 13/25
# 16/16 [==============================] - 2s 119ms/step - loss: 2.1379 - categorical_accuracy: 0.6957 - val_loss: 2.0984 - val_categorical_accuracy: 0.6938
# Epoch 14/25
# 16/16 [==============================] - 2s 146ms/step - loss: 2.1077 - categorical_accuracy: 0.6948 - val_loss: 2.0876 - val_categorical_accuracy: 0.6913
# Epoch 15/25
# 16/16 [==============================] - 1s 52ms/step - loss: 2.0868 - categorical_accuracy: 0.6963 - val_loss: 2.0628 - val_categorical_accuracy: 0.6988
# Epoch 16/25
# 16/16 [==============================] - 1s 50ms/step - loss: 2.0634 - categorical_accuracy: 0.6970 - val_loss: 2.0483 - val_categorical_accuracy: 0.6925
# Epoch 17/25
# 16/16 [==============================] - 1s 52ms/step - loss: 2.0408 - categorical_accuracy: 0.6996 - val_loss: 2.0111 - val_categorical_accuracy: 0.7000
# Epoch 18/25
# 16/16 [==============================] - 1s 48ms/step - loss: 2.0244 - categorical_accuracy: 0.6973 - val_loss: 2.0256 - val_categorical_accuracy: 0.6913
# Epoch 19/25
# 16/16 [==============================] - 1s 48ms/step - loss: 2.0099 - categorical_accuracy: 0.6986 - val_loss: 1.9922 - val_categorical_accuracy: 0.7050
# Epoch 20/25
# 16/16 [==============================] - 1s 50ms/step - loss: 1.9899 - categorical_accuracy: 0.6998 - val_loss: 1.9760 - val_categorical_accuracy: 0.6988
# Epoch 21/25
# 16/16 [==============================] - 1s 52ms/step - loss: 1.9772 - categorical_accuracy: 0.6997 - val_loss: 1.9570 - val_categorical_accuracy: 0.6988
# Epoch 22/25
# 16/16 [==============================] - 1s 49ms/step - loss: 1.9635 - categorical_accuracy: 0.6998 - val_loss: 1.9436 - val_categorical_accuracy: 0.7038
# Epoch 23/25
# 16/16 [==============================] - 1s 49ms/step - loss: 1.9426 - categorical_accuracy: 0.7036 - val_loss: 1.9279 - val_categorical_accuracy: 0.7050
# Epoch 24/25
# 16/16 [==============================] - 1s 49ms/step - loss: 1.9330 - categorical_accuracy: 0.7034 - val_loss: 1.9235 - val_categorical_accuracy: 0.7100
# Epoch 25/25
# 16/16 [==============================] - 1s 50ms/step - loss: 1.9223 - categorical_accuracy: 0.7052 - val_loss: 1.9101 - val_categorical_accuracy: 0.7050

# %%
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'g--', label='Training loss')
plt.plot(epochs, val_loss_values, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()
acc_values = history_dict['categorical_accuracy']
val_acc_values = history_dict['val_categorical_accuracy']
plt.plot(epochs, acc_values, 'g--', label='Training Accuracy')
plt.plot(epochs, val_acc_values, 'r', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
